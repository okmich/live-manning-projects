# %% [markdown]
# # Hello PyCaret Classification.
# https://pycaret.gitbook.io/docs/get-started/quickstart

# %%
# load sample dataset
from pycaret.classification import ClassificationExperiment
from pycaret.datasets import get_data

data = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
s = ClassificationExperiment()
s.setup(data, target = 'Class variable', session_id = 123)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 2
#       1 s = ClassificationExperiment()
# ----> 2 s.setup(data, target = 'Class variable', session_id = 123)
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/pycaret/classification/oop.py:785, in ClassificationExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     768 self._prepare_folds(
#     769     fold_strategy=fold_strategy,
#     770     fold=fold,
#     771     fold_shuffle=fold_shuffle,
#     772     fold_groups=fold_groups,
#     773 )
#     775 self._prepare_column_types(
#     776     ordinal_features=ordinal_features,
#     777     numeric_features=numeric_features,
#    (...)
#     782     keep_features=keep_features,
#     783 )
# --> 785 self._set_exp_model_engines(
#     786     container_default_engines=get_container_default_engines(),
#     787     engine=engine,
#     788 )
#     790 # Preprocessing ============================================ >>
#     791
#     792 # Initialize empty pipeline
#     793 self.pipeline = InternalPipeline(
#     794     steps=[("placeholder", None)],
#     795     memory=self.memory,
#     796 )
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:2890, in _TabularExperiment._set_exp_model_engines(self, container_default_engines, engine)
#    2887 for key in container_default_engines:
#    2888     # If provided by user, then use that, else get from the defaults
#    2889     eng = engine.get(key, container_default_engines.get(key))
# -> 2890     self._set_engine(estimator=key, engine=eng, severity="error")
#    2892 return self
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:2856, in _TabularExperiment._set_engine(self, estimator, engine, severity)
#    2851     self.logger.info(
#    2852         f"Engine successfully changes for model '{estimator}' to '{engine}'."
#    2853     )
#    2855 # Need to do this, else internal class variables are not reset with new engine.
# -> 2856 self._set_all_models()
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:2746, in _TabularExperiment._set_all_models(self)
#    2738 def _set_all_models(self) -> "_TabularExperiment":
#    2739     """Set all available models
#    2740
#    2741     Returns
#    (...)
#    2744         The experiment object to allow chaining of methods
#    2745     """
# -> 2746     self._all_models, self._all_models_internal = self._get_models()
#    2747     return self
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/pycaret/classification/oop.py:84, in ClassificationExperiment._get_models(self, raise_errors)
#      81 def _get_models(self, raise_errors: bool = True) -> Tuple[dict, dict]:
#      82     all_models = {
#      83         k: v
# ---> 84         for k, v in get_all_class_model_containers(
#      85             self, raise_errors=raise_errors
#      86         ).items()
#      87         if not v.is_special
#      88     }
#      89     all_models_internal = get_all_class_model_containers(
#      90         self, raise_errors=raise_errors
#      91     )
#      92     return all_models, all_models_internal
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/pycaret/containers/models/classification.py:1640, in get_all_model_containers(experiment, raise_errors)
#    1637 def get_all_model_containers(
#    1638     experiment: Any, raise_errors: bool = True
#    1639 ) -> Dict[str, ClassifierContainer]:
# -> 1640     return pycaret.containers.base_container.get_all_containers(
#    1641         globals(), experiment, ClassifierContainer, raise_errors
#    1642     )
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/pycaret/containers/base_container.py:119, in get_all_containers(container_globals, experiment, type_var, raise_errors)
#     117 if hasattr(obj, "active") and not obj.active:
#     118     continue
# --> 119 instance = obj(experiment)
#     120 if instance.active:
#     121     model_containers.append(instance)
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/pycaret/containers/models/classification.py:1254, in LGBMClassifierContainer.__init__(self, experiment)
#    1252 get_logger()
#    1253 np.random.seed(experiment.seed)
# -> 1254 from lightgbm import LGBMClassifier
#    1255 from lightgbm.basic import LightGBMError
#    1257 args = {
#    1258     "random_state": experiment.seed,
#    1259     "n_jobs": experiment.n_jobs_param,
#    1260 }
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/lightgbm/__init__.py:8
#       2 """LightGBM, Light Gradient Boosting Machine.
#       3
#       4 Contributors: https://github.com/microsoft/LightGBM/graphs/contributors.
#       5 """
#       6 from pathlib import Path
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import early_stopping, log_evaluation, print_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/lightgbm/basic.py:110
#     106         raise LightGBMError(lib.LGBM_GetLastError().decode('utf-8'))
#     107     return lib
# --> 110 _LIB = _load_lib()
#     113 NUMERIC_TYPES = (int, float, bool)
#     116 def _safe_call(ret: int) -> None:
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/lightgbm/basic.py:101, in _load_lib()
#      99 if len(lib_path) == 0:
#     100     return None
# --> 101 lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     102 lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     103 callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/ctypes/__init__.py:452, in LibraryLoader.LoadLibrary(self, name)
#     451 def LoadLibrary(self, name):
# --> 452     return self._dlltype(name)
#
# File ~/opt/anaconda3/envs/autopycaret/lib/python3.10/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371 self._FuncPtr = _FuncPtr
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#     376     self._handle = handle
#
# OSError: dlopen(/Users/Michael_Enudi/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/Michael_Enudi/opt/anaconda3/envs/autopycaret/lib/python3.10/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)

# %%
best = s.compare_models()
