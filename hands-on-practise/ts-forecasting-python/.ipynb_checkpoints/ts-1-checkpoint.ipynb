# %%
import numpy as np
import pandas as pd

# %%
raw_csv_data = pd.read_csv('Index2018.csv')
index2018_df = raw_csv_data.copy()
index2018_df.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
index2018_df.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %% [markdown]
# ## plot data

# %%
import matplotlib.pyplot as plt

# %%
index2018_df['spx'].pindex2018_dftle='S&P PRices', figsize=(20,6))
# Out:
# <AxesSubplot:title={'center':'S&P PRices'}>

# %%
index2018_df['ftse'].plot(title='FTSE PRices', figsize=(20,6))
plt.show()

# %% [markdown]
# ### The QQ Plot

# %%
import scipy.stats
import pylab
# Out:
# /Users/Michael_Enudi/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
scipy.stats.probplot(index2018_df['dax'], plot = pylab)
plt.show()

# %% [markdown]
# ### QQ Plot - another way

# %%
import statsmodels.api as sm

sm.qqplot(index2018_df.spx, fit=True, line='45')
plt.show()
